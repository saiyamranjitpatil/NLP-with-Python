# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# 2026-07-23 09:53:37.864 python[2293:25637] +[IMKClient subclass]: chose IMKClient_Modern
# 2026-07-23 09:53:37.864 python[2293:25637] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# True

# %%
from nltk.book import *

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text1.concordance("hi")
# Out:
# no matches

# %%
text1.concordance("flood")
# Out:
# Displaying 15 of 15 matches:
# " -- MONTGOMERY ' S WORLD BEFORE THE FLOOD . " Io ! Paean ! Io ! sing . To the
# aling voyage was welcome ; the great flood - gates of the wonder - world swung
#  animated mass that has survived the flood ; most monstrous and most mountainou
# lies his business , which a Noah ' s flood would not interrupt , though it over
# ship swinging to her anchor with the flood - tide , was now obliquely pointing
# - " Sweet fields beyond the swelling flood , Stand dressed in living green . So
# r . Yea , foolish mortals , Noah ' s flood is not yet subsided ; two thirds of
#  animals there are certain valves or flood - gates in many of their veins , whe
# you carry them the news that another flood had come ; they would only answer --
# r incalculable seniors ; I am , by a flood , borne back to that wondrous period
# stle , and the Kremlin . In Noah ' s flood he despised Noah ' s Ark ; and if ev
# ...

# %%
text1.similar("monstrous")
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
text2.similar("monstrous")
# Out:
# very so exceedingly heartily a as good great extremely remarkably
# sweet vast amazingly

# %%
text4.dispersion_plot(["citizens","democracy"])

# %%
# Create an initial list of items
shopping_list = ["apples", "milk", "bread"]
shopping_list
# Out:
# ['apples', 'milk', 'bread']

# %%
len(text1)
# Out:
# 260819

# %%
set(text2)
# Out:
# {'fifty',
#  'lifting',
#  'ESTEEM',
#  'screams',
#  'Plymouth',
#  'adequate',
#  'starting',
#  'devoted',
#  'restoring',
#  'slighting',
#  'elsewhere',
#  'November',
#  'apologize',
#  'disgusted',
#  'left',
#  'kneeling',
#  'ungracious',
#  'Ellisons',
#  'ingratitude',
#  'plantations',
#  'dispirited',
#  'comprehension',
#  'tricks',
#  'experience',
#  'mohrs',
#  'misconstruction',
#  'immoderately',
#  'newer',
#  'doubtful',
#  'this',
#  'tending',
#  'obviating',
#  'attainable',
#  'whatever',
#  'amount',
#  'modestest',
#  'consented',
#  'judgment',
#  'mix',
#  'subsequent',
#  'repent',
#  'storm',
#  'taverns',
#  'landlord',
#  'cheerfulness',
#  'assented',
#  'destiny',
#  'affliction',
#  'colouring',
#  'head',
#  'conclusion',
#  'unreserve',
#  'meantime',
#  'expressions',
#  'abominably',
#  'Dennison',
#  'accidental',
#  'modesty',
#  'worthless',
#  'arrive',
#  'silly',
#  'choice',
#  'unbounded',
#  'pecuniary',
#  'reanimate',
#  'elegant',
# ...

# %%
# Add "eggs" to the end
shopping_list.append("eggs")

shopping_list
# Out:
# ['apples', 'milk', 'bread', 'eggs']

# %%
# Insert "coffee" at index 1 (the 2nd position)
shopping_list.insert(1, "coffee")

shopping_list
# Out:
# ['apples', 'coffee', 'milk', 'bread', 'eggs']

# %%
new_items = ["butter", "cheese"]
shopping_list.extend(new_items)

shopping_list
# Out:
# ['apples', 'coffee', 'milk', 'bread', 'eggs', 'butter', 'cheese']

# %%
len(set(text2))/len(text2)
# Out:
# 0.04826383002768831

# %%
len(set(text3))/len(text3)
# Out:
# 0.06230453042623537

# %%
len(set(text1))/len(text1)
# Out:
# 0.07406285585022564

# %%
text1.count("Monstrous")
# Out:
# 1
